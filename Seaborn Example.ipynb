# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('nba_2017_players_with_salary_wiki_twitter.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Rk             PLAYER POSITION  AGE    MP    FG   FGA    FG%  \
# 0           0   1  Russell Westbrook       PG   28  34.6  10.2  24.0  0.425
# 1           1   2       James Harden       PG   27  36.4   8.3  18.9  0.440
# 2           2   4      Anthony Davis        C   23  36.1  10.3  20.3  0.505
# 3           3   6   DeMarcus Cousins        C   26  34.2   9.0  19.9  0.452
# 4           4   7     Damian Lillard       PG   26  35.9   8.8  19.8  0.444
#
#     3P  ...  DRPM   RPM  WINS_RPM   PIE    PACE   W  SALARY_MILLIONS  \
# 0  2.5  ... -0.47  6.27     17.34  23.0  102.31  46            26.50
# 1  3.2  ... -1.57  4.81     15.54  19.0  102.98  54            26.50
# 2  0.5  ...  3.90  4.35     12.81  19.2  100.19  31            22.12
# 3  1.8  ...  0.64  4.20     11.26  17.8   97.11  30            16.96
# 4  2.9  ... -1.49  3.14     10.72  15.9   99.68  38            24.33
#
#    PAGEVIEWS  TWITTER_FAVORITE_COUNT  TWITTER_RETWEET_COUNT
# ...

# %%
g=sns.boxplot(x='RPM',data=df)

# %%
g = sns.lmplot(x='RPM', y='WINS_RPM', hue='POSITION',data=df)
plt.show()

# %%
g = sns.lineplot(x='RPM', y='WINS_RPM', hue='POSITION', data=df)
plt.show()

# %%
g = sns.scatterplot(x='RPM', y='WINS_RPM', hue='POSITION',data=df)
plt.show()

# %%
g = sns.relplot(x='RPM', y='WINS_RPM', hue='POSITION',data=df)
plt.show()

# %% [markdown]
# All these plots tell a similar story. The benefit of the 1st plot, the lmplot, is that it shows a line of best fit and confidence interval to the data. However, unlike the scatter and relplots, you are unable to see a lot of the data points as they are on top of each other and jumbled together.

# %%
g = sns.boxplot(x='POSITION',y='WINS_RPM',data=df)

# %%
g = sns.catplot(x='POSITION',y='WINS_RPM',data=df)

# %%
g=sns.barplot(x='POSITION',y='WINS_RPM',data=df)

# %%
g=sns.swarmplot(x='POSITION',y='WINS_RPM',data=df)

# %%
g=sns.violinplot(x='POSITION',y='WINS_RPM',data=df)

# %%
g=sns.boxenplot(x='POSITION',y='WINS_RPM',data=df)

# %%
PG_3p = df.loc[df['POSITION'] == 'PG', '3P%']
SG_3p = df.loc[df['POSITION'] == 'SG', '3P%']
SF_3p = df.loc[df['POSITION'] == 'SF', '3P%']
PF_3p = df.loc[df['POSITION'] == 'PF', '3P%']
C_3p = df.loc[df['POSITION'] == 'C', '3P%']

# %%
sns.distplot(PG_3p)
